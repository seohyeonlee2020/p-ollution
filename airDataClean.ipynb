# %%
import pandas as pd
import numpy as np
import os
import re

# %%
directory = "rawdata"

#loop through data folder and open each file as csv. take name from disease code
df_list = []
title_list = []
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)

    # checking if it is a file
    if os.path.isfile(f):
        title = filename.split('.')[0]
        title_list.append(title)
        if filename.split('.')[1] == "csv":
            title = pd.read_csv(f)
           
        elif filename.split('.')[1] == "xlsx":
            title = pd.read_excel(f)
        df_list.append(title)
        #print(title[:4])
# Out:
# /Users/seohyeonlee/p-ollution/.venv/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/seohyeonlee/p-ollution/.venv/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
print(title_list)
# Out:
# ['no2', 'sox', 'ozone', 'co', 'pm10']

# %%
#horizontally merge everything. region name + pollutant name (filename here)

df_list[0] = df_list[0].transpose()
df_list[0].columns = 

#find level 2 columns named "average for provinces" and rename them as [classification 1] + average

for elem in df.iloc["Classification"]
# Out:
#                            0       1       2       3        4        5    \
# Classification(1)        Total   Seoul   Busan   Daegu  Incheon  Gwangju
# Classification(2)  Sub Summary   Seoul   Busan   Daegu  Incheon  Gwangju
# 2017.01                 0.0270  0.0350  0.0240  0.0280   0.0270   0.0230
# 2017.02                 0.0250  0.0350  0.0210  0.0250   0.0260   0.0220
# 2017.03                 0.0270  0.0380  0.0220  0.0240   0.0300   0.0250
# ...                        ...     ...     ...     ...      ...      ...
# 2022.08                 0.0090  0.0130  0.0110  0.0090   0.0110   0.0070
# 2022.09                 0.0100  0.0160  0.0100  0.0100   0.0150   0.0110
# 2022.10                 0.0130  0.0200  0.0130  0.0140   0.0190   0.0140
# 2022.11                 0.0190  0.0280  0.0190  0.0250   0.0260   0.0210
# 2022.12                  0.019   0.028   0.017   0.023    0.024    0.022
#
#                        6       7          8         9    ...        162  \
# ...
